# %%
import pytz
import telebot
import schedule
import time
import pandas as pd
import pyodbc

# %%
import datetime

current_time = datetime.datetime.now()
time_str = "{:02d}:{:02d}".format(current_time.hour, current_time.minute)
print(time_str)
# Out:
# 12:42

# %%
if time_str == "12:42":
    print(3)
# Out:
# 3

# %%
import pytz
import telebot
import time
import pandas as pd
import pyodbc
import time
import datetime

server = '172.17.1.92'
database = 'Insurance'
username = 'ali.akhymbek'
password = 'b7Zc4FDe'  
cnxn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER='+server+';DATABASE='+database+';UID='+username+';PWD='+ password)
cursor = cnxn.cursor()



server_2 = '10.48.128.101'
database_2 = 'ins_da'
username_2 = 'ins_user'
password_2 = 'wgGH^%$D47'  
cnxn_2 = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER='+server+';DATABASE='+database+';UID='+username+';PWD='+ password)
cursor_2 = cnxn_2.cursor()




# Ali
# bot_token = '5876608578:AAHDV5nBx7f7SiDPx6gR6eqNM9HvmnR-bg4'
# chat_id = '-1001611218530'  # ID чата, куда будут отправляться сообщения
# bot = telebot.TeleBot(bot_token)



# Dias
bot_token = '7066712051:AAGhCupoqcKfBy58gOlvZ7uOibHnqECeNHo'
chat_id = '691506976'
bot = telebot.TeleBot(bot_token)


# MAIN
# bot_token = '6086453765:AAEObRkbVv_gHC48PS0rGwxWA1uj1rJeaTM'
# chat_id = '-931946502'  # ID чата, куда будут отправляться сообщения
# bot = telebot.TeleBot(bot_token)







def insurance_acts():
    query = """
    select count(*) as cnt
    from   [Insurance].[dbo].[insurance_acts]
    where cast(Created_At as date) = dateadd(day, -1, cast(getdate() as date))
    """
    df = pd.read_sql(query, cnxn_2)
    cnt = df.iloc[0]['cnt']

    if cnt == 0:
        return "За вчера в таблице <b>Insurance.dbo.insurance_acts</b> нет данных \U0001F525"





def loss_statements():
    query = """
    select count(*) as cnt
    from Insurance.dbo.loss_statements
    where cast(Created_At as date) = dateadd(day, -1, cast(getdate() as date))
    """
    df = pd.read_sql(query, cnxn_2)
    cnt = df.iloc[0]['cnt']

    if cnt == 0:
        return  "За вчера в таблице <b>Insurance.dbo.loss_statements</b> нет данных \U0001F525 "


def loss_notices():
    query = """
    select count(*) as cnt
    from Insurance.dbo.loss_notices
    where cast(Created_At as date) = dateadd(day, -1, cast(getdate() as date))
    """
    df = pd.read_sql(query, cnxn_2)
    cnt = df.iloc[0]['cnt']

    if cnt == 0:
        return  "За вчера в таблице <b>nsurance.dbo.loss_notices</b> нет данных \U0001F525 "



def kasko_cars():
    query = """
    select count(id) as cnt
    from ins_da.db_owner.kasko_cars
    where cast(created_at as date) = dateadd(day, -1, cast(getdate() as date))
    """
    df = pd.read_sql(query, cnxn)
    cnt = df.iloc[0]['cnt']

    if cnt == 0:
        return  "За вчера в таблице <b>ins_da.db_owner.kasko_cars</b> нет данных \U0001F525 "



def kasko_payments():
    query = """
    select count(id) as cnt
    from ins_da.db_owner.kasko_payments
    where cast(created_at as date) = dateadd(day, -1, cast(getdate() as date))
    """
    df = pd.read_sql(query, cnxn)
    cnt = df.iloc[0]['cnt']

    if cnt == 0:
        return  "За вчера в таблице <b>ins_da.db_owner.kasko_payments</b> нет данных \U0001F525 "



def kasko_pb_cards():
    query = """
    select count(id) as cnt
    from ins_da.db_owner.kasko_pb_cards
    where cast(created_at as date) = dateadd(day, -1, cast(getdate() as date))
    """
    df = pd.read_sql(query, cnxn)
    cnt = df.iloc[0]['cnt']

    if cnt == 0:
        return  "За вчера в таблице <b>ins_da.db_owner.kasko_pb_cards</b> нет данных \U0001F525 "



def kasko_pb_payments():
    query = """
    select count(id) as cnt
    from ins_da.db_owner.kasko_pb_payments
    where cast(insert_dt as date) = dateadd(day, -1, cast(getdate() as date))
    """
    df = pd.read_sql(query, cnxn)
    cnt = df.iloc[0]['cnt']

    if cnt == 0:
        return  "За вчера в таблице <b>ins_da.db_owner.kasko_pb_payment</b>s нет данных \U0001F525 "



def kasko_subscription():
    query = """
    select count(id) as cnt
    from ins_da.db_owner.kasko_subscription
    where cast(insert_dt as date) = dateadd(day, -1, cast(getdate() as date))
    """
    df = pd.read_sql(query, cnxn)
    cnt = df.iloc[0]['cnt']

    if cnt == 0:
        return  "За вчера в таблице <b>ins_da.db_owner.kasko_subscription</b> нет данных \U0001F525 "




def yandex_metrica_hits():
    query = """
    select count(id) as cnt
    from ins_da.db_owner.yandex_metrica_hits
    where cast(dateTime as date) = dateadd(day, -1, cast(getdate() as date))
    """
    df = pd.read_sql(query, cnxn)
    cnt = df.iloc[0]['cnt']

    if cnt == 0:
        return  "За вчера в таблице <b>ins_da.db_owner.yandex_metrica_hits</b> нет данных \U0001F525 "



def yandex_metrica_visits():
    query = """
    select count(id) as cnt
    from ins_da.db_owner.yandex_metrica_visits
    where cast(dateTime as date) = dateadd(day, -1, cast(getdate() as date))
    """
    df = pd.read_sql(query, cnxn)
    cnt = df.iloc[0]['cnt']

    if cnt == 0:
        return  "За вчера в таблице <b>ins_da.db_owner.yandex_metrica_visits</b> нет данных \U0001F525 "



def user_errors():
    query = """
    select count(id) as cnt
    from ins_da.db_owner.user_errors
    where cast(insert_dt as date) = dateadd(day, -1, cast(getdate() as date))
    """
    df = pd.read_sql(query, cnxn)
    cnt = df.iloc[0]['cnt']

    if cnt == 0:
        return  "За вчера в таблице <b>ins_da.db_owner.user_errors</b> нет данных \U0001F525 "



def kasko_calcs():
    query = """
    select count(id) as cnt
    from ins_da.db_owner.kasko_calcs
    where cast(insert_dt as date) = dateadd(day, -1, cast(getdate() as date))
    """
    df = pd.read_sql(query, cnxn)
    cnt = df.iloc[0]['cnt']

    if cnt == 0:
        return  "За вчера в таблице <b>ins_da.db_owner.kasko_calcs</b> нет данных \U0001F525 "




    
message = "За вчера нет данных в таблицах \U0001F525:"
message=message+"\n\n"
result_functions = [
    kasko_cars, kasko_payments,
    kasko_pb_cards, kasko_pb_payments, kasko_subscription, yandex_metrica_hits, yandex_metrica_visits,
    user_errors, kasko_calcs
]

result_functions_insurance = [
    insurance_acts, loss_statements, loss_notices
]







error_functions = []


for func in result_functions:
    result = func()
    if result is not None:
        message += f"<b>{func.__name__}</b>"+"\n\n"
        error_functions.append(func)


for func in result_functions_insurance:
    result = func()
    if result is not None:
        message += f"<b>{func.__name__}</b>"+"\n\n"
        error_functions.append(func)

print(error_functions)

error_functions_name = [func.__name__ for func in error_functions]
error_functions_name = [error + "_2" for error in error_functions_name]
print(error_functions_name)


error_functions_2 = []




# file_path = "/home/tester/dias_alerts/functions.txt"

# with open(file_path, "w") as file:
#     for func in error_functions_name:
#         file.write(func + "\n")



# bot.send_message(chat_id, message, parse_mode='HTML')
# Out:
# C:\Users\dias.issabekov\AppData\Local\Temp\ipykernel_8156\409587363.py:101: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, cnxn)
# C:\Users\dias.issabekov\AppData\Local\Temp\ipykernel_8156\409587363.py:115: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, cnxn)
# C:\Users\dias.issabekov\AppData\Local\Temp\ipykernel_8156\409587363.py:129: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, cnxn)
# ...

# %%
check_and_send_message
# Out:
# <function __main__.check_and_send_message()>

# %%
df

7066712051:AAGhCupoqcKfBy58gOlvZ7uOibHnqECeNHo
# Out:
#      cnt
# 0  48116

# %%
import telebot
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 2
#       1 import telebot
# ----> 2 import config
#
# ModuleNotFoundError: No module named 'config'
